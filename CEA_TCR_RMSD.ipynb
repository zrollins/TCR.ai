# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Chain A (MHC) vs Time
a, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000001/A_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            a.append(float(cols[1]))

#Chain B (B2M) vs Time

            
b, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000001/B_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            b.append(float(cols[1]))

#Chain C (GVA) vs Time

            
c, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000001/C_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            c.append(float(cols[1]))

#Chain D (TCRa) vs Time

            
d, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000001/D_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            d.append(float(cols[1]))
            
#Chain E (TCRb) vs Time

            
e, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000001/E_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            e.append(float(cols[1]))
#TCR-peptide H_Number vs Time

cdr3a, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000001/CDR3a_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            cdr3a.append(float(cols[1]))
            
cdr3b, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000001/CDR3b_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            cdr3b.append(float(cols[1]))
#TCR-peptide H_Number vs Time
#TCR-peptide H_Number vs Time


#PLOT Chain RMSD

rmsd = {'Time (ns)': t,'MHCα':a,'β2M':b,'CEA':c,'TCRα':d,'TCRβ':e,'CDR3α':cdr3a,'CDR3β':cdr3b}
df = pd.DataFrame(rmsd)
#df['Peptide SMA']= df.iloc[:,1].rolling(window=200).mean()
#df['MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ns)', y='MHCα', color='gray', ax=ax)
df.plot(kind='line',x='Time (ns)', y='β2M', color= 'black', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CEA', color='purple', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRα', color='maroon', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRβ', color='red', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CDR3α', color='lime', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CDR3β', color='forestgreen', ax=ax)
ax.set_ylabel('RMSD (nm)', fontname = 'Arial', fontsize=20)
ax.set_xlabel('Time (ps)', fontname = 'Arial', fontsize=20)
ax.set_title('TCR1 Equilibration', fontname = 'Arial Black', fontsize=20)

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.savefig('/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000001/RMSD.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Chain A (MHC) vs Time
a, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000002/A_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            a.append(float(cols[1]))

#Chain B (B2M) vs Time

            
b, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000002/B_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            b.append(float(cols[1]))

#Chain C (GVA) vs Time

            
c, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000002/C_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            c.append(float(cols[1]))

#Chain D (TCRa) vs Time

            
d, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000002/D_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            d.append(float(cols[1]))
            
#Chain E (TCRb) vs Time

            
e, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000002/E_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            e.append(float(cols[1]))
#TCR-peptide H_Number vs Time

cdr3a, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000002/CDR3a_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            cdr3a.append(float(cols[1]))
            
cdr3b, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000002/CDR3b_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            cdr3b.append(float(cols[1]))
#TCR-peptide H_Number vs Time
#TCR-peptide H_Number vs Time


#PLOT Chain RMSD

rmsd = {'Time (ns)': t,'MHCα':a,'β2M':b,'CEA':c,'TCRα':d,'TCRβ':e,'CDR3α':cdr3a,'CDR3β':cdr3b}
df = pd.DataFrame(rmsd)
#df['Peptide SMA']= df.iloc[:,1].rolling(window=200).mean()
#df['MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ns)', y='MHCα', color='gray', ax=ax)
df.plot(kind='line',x='Time (ns)', y='β2M', color= 'black', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CEA', color='purple', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRα', color='maroon', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRβ', color='red', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CDR3α', color='magenta', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CDR3β', color='pink', ax=ax)
ax.set_ylabel('RMSD (nm)', fontname = 'Arial', fontsize=20)
ax.set_xlabel('Time (ps)', fontname = 'Arial', fontsize=20)
ax.set_title('TCR2 Equilibration', fontname = 'Arial Black', fontsize=20)

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.savefig('/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000002/RMSD_CDR3.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Chain A (MHC) vs Time
a, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000003/A_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            a.append(float(cols[1]))

#Chain B (B2M) vs Time

            
b, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000003/B_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            b.append(float(cols[1]))

#Chain C (GVA) vs Time

            
c, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000003/C_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            c.append(float(cols[1]))

#Chain D (TCRa) vs Time

            
d, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000003/D_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            d.append(float(cols[1]))
            
#Chain E (TCRb) vs Time

            
e, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000003/E_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            e.append(float(cols[1]))
#TCR-peptide H_Number vs Time

cdr3a, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000003/CDR3a_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            cdr3a.append(float(cols[1]))
            
cdr3b, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000003/CDR3b_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            cdr3b.append(float(cols[1]))
#TCR-peptide H_Number vs Time
#TCR-peptide H_Number vs Time


#PLOT Chain RMSD

rmsd = {'Time (ns)': t,'MHCα':a,'β2M':b,'CEA':c,'TCRα':d,'TCRβ':e,'CDR3α':cdr3a,'CDR3β':cdr3b}
df = pd.DataFrame(rmsd)
#df['Peptide SMA']= df.iloc[:,1].rolling(window=200).mean()
#df['MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ns)', y='MHCα', color='gray', ax=ax)
df.plot(kind='line',x='Time (ns)', y='β2M', color= 'black', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CEA', color='purple', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRα', color='maroon', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRβ', color='red', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CDR3α', color='blue', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CDR3β', color='cornflowerblue', ax=ax)
ax.set_ylabel('RMSD (nm)', fontname = 'Arial', fontsize=20)
ax.set_xlabel('Time (ps)', fontname = 'Arial', fontsize=20)
ax.set_title('TCR3 Equilibration', fontname = 'Arial Black', fontsize=20)

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.savefig('/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000003/RMSD.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Chain A (MHC) vs Time
a, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000004/A_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            a.append(float(cols[1]))

#Chain B (B2M) vs Time

            
b, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000004/B_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            b.append(float(cols[1]))

#Chain C (GVA) vs Time

            
c, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000004/C_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            c.append(float(cols[1]))

#Chain D (TCRa) vs Time

            
d, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000004/D_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            d.append(float(cols[1]))
            
#Chain E (TCRb) vs Time

            
e, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000004/E_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            e.append(float(cols[1]))
#TCR-peptide H_Number vs Time

cdr3a, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000004/CDR3a_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            cdr3a.append(float(cols[1]))
            
cdr3b, t = [], []

with open("/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000004/CDR3b_RMSD.xvg") as f:
    #lines = (line for line in f if not line.startsiwith('#') if not line.startswith('$'))
    for line in f:
        if line.startswith('#'):
            continue
        if line.startswith('@'):
            continue
        cols = line.split()

        if len(cols) == 2:
            t.append(float(cols[0]))
            cdr3b.append(float(cols[1]))
#TCR-peptide H_Number vs Time
#TCR-peptide H_Number vs Time


#PLOT Chain RMSD

rmsd = {'Time (ns)': t,'MHCα':a,'β2M':b,'CEA':c,'TCRα':d,'TCRβ':e,'CDR3α':cdr3a,'CDR3β':cdr3b}
df = pd.DataFrame(rmsd)
#df['Peptide SMA']= df.iloc[:,1].rolling(window=200).mean()
#df['MHC SMA']= df.iloc[:,2].rolling(window=200).mean()
ax = plt.gca()
df.plot(kind='line',x='Time (ns)', y='MHCα', color='darkgreen', ax=ax)
df.plot(kind='line',x='Time (ns)', y='β2M', color= 'green', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CEA', color='purple', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRα', color='blue', ax=ax)
df.plot(kind='line',x='Time (ns)', y='TCRβ', color='red', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CDR3α', color='cornflowerblue', ax=ax)
df.plot(kind='line',x='Time (ns)', y='CDR3β', color='tomato', ax=ax)
ax.set_ylabel('RMSD (nm)', fontname = 'Arial', fontsize=20)
ax.set_xlabel('Time (ps)', fontname = 'Arial', fontsize=20)
ax.set_title('TCR4 Equilibration', fontname = 'Arial Black', fontsize=20)

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.savefig('/Users/zrollins/Documents/Documents/AI_Patent/CEA/TCR000004/RMSD.png', bbox_inches='tight', dpi=300)
plt.show()
